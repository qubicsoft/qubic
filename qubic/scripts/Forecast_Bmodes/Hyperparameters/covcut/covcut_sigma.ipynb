# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# ## Fitted parameter results vs Coverage cut

# %%
cov_cut = [0.001, 0.005, 0.01, 0.015, 0.02, 0.025, 0.03]

data = {
    'QUBIC':                        [(-0.011, 0.578), (0.004, 0.056), (-0.002, 0.038), (-0.004, 0.032), (-0.002, 0.032), (-0.001, 0.032), (0.001, 0.034)],
    'QUBIC + Planck (143+217+353)': [(-0.003, 0.082), (-0.004, 0.020), (-0.004, 0.020), (-0.001, 0.016), (0.001, 0.012), (-0.002, 0.015), (-0.003, 0.018)],
}

def fmt(val, err):
    return f'{val:+.3f} ± {err:.3f}'

rows = []
for i, n in enumerate(cov_cut):
    rows.append({
        'cov_cut': n,
        **{cfg: fmt(*data[cfg][i]) for cfg in data}
    })

df = pd.DataFrame(rows).set_index('cov_cut')

df.style \
    .set_caption('Fitted parameter (r ± σ) for different configurations') \
    .set_table_styles([
        {'selector': 'caption', 'props': [('font-size', '13px'), ('font-weight', 'bold'), ('text-align', 'left'), ('padding-bottom', '6px')]},
        {'selector': 'th',      'props': [('background-color', '#2c3e50'), ('color', 'white'), ('padding', '6px 14px'), ('text-align', 'center')]},
        {'selector': 'td',      'props': [('padding', '5px 14px'), ('text-align', 'center'), ('font-family', 'monospace')]},
        {'selector': 'tr:nth-child(even)', 'props': [('background-color', "#f0f4f800")]},
    ])
# Out:
# <style type="text/css">
# #T_7221c caption {
#   font-size: 13px;
#   font-weight: bold;
#   text-align: left;
#   padding-bottom: 6px;
# }
# #T_7221c th {
#   background-color: #2c3e50;
#   color: white;
#   padding: 6px 14px;
#   text-align: center;
# }
# #T_7221c td {
#   padding: 5px 14px;
#   text-align: center;
#   font-family: monospace;
# }
# #T_7221c tr:nth-child(even) {
#   background-color: #f0f4f800;
# }
# </style>
# <table id="T_7221c">
#   <caption>Fitted parameter (r ± σ) for different configurations</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7221c_level0_col0" class="col_heading level0 col0" >QUBIC</th>
#       <th id="T_7221c_level0_col1" class="col_heading level0 col1" >QUBIC + Planck (143+217+353)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cov_cut</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7221c_level0_row0" class="row_heading level0 row0" >0.001000</th>
#       <td id="T_7221c_row0_col0" class="data row0 col0" >-0.011 ± 0.578</td>
#       <td id="T_7221c_row0_col1" class="data row0 col1" >-0.003 ± 0.082</td>
#     </tr>
#     <tr>
#       <th id="T_7221c_level0_row1" class="row_heading level0 row1" >0.005000</th>
#       <td id="T_7221c_row1_col0" class="data row1 col0" >+0.004 ± 0.056</td>
#       <td id="T_7221c_row1_col1" class="data row1 col1" >-0.004 ± 0.020</td>
#     </tr>
#     <tr>
#       <th id="T_7221c_level0_row2" class="row_heading level0 row2" >0.010000</th>
#       <td id="T_7221c_row2_col0" class="data row2 col0" >-0.002 ± 0.038</td>
#       <td id="T_7221c_row2_col1" class="data row2 col1" >-0.004 ± 0.020</td>
#     </tr>
#     <tr>
#       <th id="T_7221c_level0_row3" class="row_heading level0 row3" >0.015000</th>
#       <td id="T_7221c_row3_col0" class="data row3 col0" >-0.004 ± 0.032</td>
#       <td id="T_7221c_row3_col1" class="data row3 col1" >-0.001 ± 0.016</td>
#     </tr>
#     <tr>
#       <th id="T_7221c_level0_row4" class="row_heading level0 row4" >0.020000</th>
#       <td id="T_7221c_row4_col0" class="data row4 col0" >-0.002 ± 0.032</td>
#       <td id="T_7221c_row4_col1" class="data row4 col1" >+0.001 ± 0.012</td>
#     </tr>
#     <tr>
#       <th id="T_7221c_level0_row5" class="row_heading level0 row5" >0.025000</th>
#       <td id="T_7221c_row5_col0" class="data row5 col0" >-0.001 ± 0.032</td>
#       <td id="T_7221c_row5_col1" class="data row5 col1" >-0.002 ± 0.015</td>
#     </tr>
#     <tr>
#       <th id="T_7221c_level0_row6" class="row_heading level0 row6" >0.030000</th>
#       <td id="T_7221c_row6_col0" class="data row6 col0" >+0.001 ± 0.034</td>
#       <td id="T_7221c_row6_col1" class="data row6 col1" >-0.003 ± 0.018</td>
#     </tr>
#   </tbody>
# </table>

# %%
from matplotlib.lines import Line2D

NSIGMA = 2  # consistency threshold: fail if |val| > NSIGMA * err

def is_failed(val, err):
    if err == 0:
        return True           # hit prior boundary
    return abs(val) / err > NSIGMA

configs = list(data.keys())
colors  = ['#2980b9', '#e67e22', '#27ae60']
markers = ['o', 's', '^']
offsets = [-0.04, 0.0, 0.04]

idx_cov_cut = np.arange(len(cov_cut))  # evenly spaced positions so 0.001 isn't stranded far from the rest

fig, (ax_val, ax_sig) = plt.subplots(2, 1, figsize=(9, 7), sharex=True,
                                      gridspec_kw={'height_ratios': [3, 2]})
fig.subplots_adjust(hspace=0.08)

# Value panel: zoom on converged region
YLIM = 0.12

ax_val.axhline(0, color='black', lw=1, ls='--', alpha=0.4, zorder=1)

for cfg, col, mk, off in zip(configs, colors, markers, offsets):
    vals = np.array([v for v, _ in data[cfg]])
    errs = np.array([e for _, e in data[cfg]])
    ok   = np.array([not is_failed(v, e) for v, e in data[cfg]])
    x    = idx_cov_cut + off

    if ok.any():
        ax_val.errorbar(x[ok], vals[ok], yerr=errs[ok],
                        fmt=mk, color=col, label=cfg,
                        capsize=4, capthick=1.2, elinewidth=1.2,
                        markersize=7, markeredgewidth=0.8, markeredgecolor='white', zorder=3)

    for j in np.where(~ok)[0]:
        v  = vals[j]
        xi = x[j]
        at_top = v > 0
        y_edge = YLIM * 0.92 if at_top else -YLIM * 0.92
        tri    = '^' if at_top else 'v'
        ax_val.plot(xi, y_edge, marker=tri, color=col, markersize=11,
                    markeredgewidth=0, zorder=4, clip_on=False)
        ax_val.text(xi, y_edge + (0.013 if at_top else -0.013),
                    f'{v:+.3f}', ha='center',
                    va='bottom' if at_top else 'top',
                    fontsize=7.5, color=col, fontweight='bold')

ax_val.set_ylim(-YLIM, YLIM)
ax_val.set_ylabel('Fitted parameter value', fontsize=11)
ax_val.tick_params(direction='in', which='both')
ax_val.yaxis.set_minor_locator(ticker.AutoMinorLocator())
ax_val.grid(axis='y', which='major', ls=':', alpha=0.4)

handles, labels = ax_val.get_legend_handles_labels()
extra = [
    Line2D([0], [0], marker='^', color='grey', ls='none', markersize=9,
           markeredgewidth=0, label=f'Failed fit (|r|>{NSIGMA}σ, off-scale)'),
]
ax_val.legend(handles + extra, labels + [h.get_label() for h in extra],
              framealpha=0.9, fontsize=9, ncol=2, loc='upper right')

# Sigma panel
for cfg, col, mk, off in zip(configs, colors, markers, offsets):
    vals = np.array([v for v, _ in data[cfg]])
    errs = np.array([e for _, e in data[cfg]])
    ok   = np.array([not is_failed(v, e) for v, e in data[cfg]])
    x    = idx_cov_cut

    if ok.any():
        ax_sig.plot(x[ok], errs[ok], mk + '-', color=col, markersize=7,
                    markeredgewidth=0.8, markeredgecolor='white', zorder=3)
    if (~ok).any():
        ax_sig.plot(x[~ok], np.where(errs[~ok] > 0, errs[~ok], 1e-4),
                    marker='x', color=col, ls='none',
                    markersize=11, markeredgewidth=2.5, zorder=4)

# ax_sig.set_yscale('log')
ax_sig.set_xticks(idx_cov_cut)
ax_sig.set_xticklabels([str(n) for n in cov_cut])
ax_sig.set_xlabel('Coverage cut', fontsize=11)
ax_sig.set_ylabel(r'Uncertainty $\sigma$', fontsize=11)
ax_sig.tick_params(direction='in', which='both', axis='both')
ax_sig.grid(axis='y', which='both', ls=':', alpha=0.4)

fig.tight_layout()
fig.suptitle('Fitted parameter vs. Coverage cut',
             fontsize=13, fontweight='bold', y=-0.01)
plt.subplots_adjust(bottom=0.1)
plt.savefig('fitted_param_vs_cov_cut.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Same plot, excluding the cov_cut = 0.001 point
cov_cut_plot = cov_cut[1:]
idx_plot     = np.arange(len(cov_cut_plot))

fig, (ax_val, ax_sig) = plt.subplots(2, 1, figsize=(9, 7), sharex=True,
                                      gridspec_kw={'height_ratios': [3, 2]})
fig.subplots_adjust(hspace=0.08)

ax_val.axhline(0, color='black', lw=1, ls='--', alpha=0.4, zorder=1)

for cfg, col, mk, off in zip(configs, colors, markers, offsets):
    vals = np.array([v for v, _ in data[cfg][1:]])
    errs = np.array([e for _, e in data[cfg][1:]])
    ok   = np.array([not is_failed(v, e) for v, e in data[cfg][1:]])
    x    = idx_plot + off

    if ok.any():
        ax_val.errorbar(x[ok], vals[ok], yerr=errs[ok],
                        fmt=mk, color=col, label=cfg,
                        capsize=4, capthick=1.2, elinewidth=1.2,
                        markersize=7, markeredgewidth=0.8, markeredgecolor='white', zorder=3)

    for j in np.where(~ok)[0]:
        v  = vals[j]
        xi = x[j]
        at_top = v > 0
        y_edge = YLIM * 0.92 if at_top else -YLIM * 0.92
        tri    = '^' if at_top else 'v'
        ax_val.plot(xi, y_edge, marker=tri, color=col, markersize=11,
                    markeredgewidth=0, zorder=4, clip_on=False)
        ax_val.text(xi, y_edge + (0.013 if at_top else -0.013),
                    f'{v:+.3f}', ha='center',
                    va='bottom' if at_top else 'top',
                    fontsize=7.5, color=col, fontweight='bold')

ax_val.set_ylim(-YLIM, YLIM)
ax_val.set_ylabel(r'r', fontsize=11)
ax_val.tick_params(direction='in', which='both')
ax_val.yaxis.set_minor_locator(ticker.AutoMinorLocator())
ax_val.grid(axis='y', which='major', ls=':', alpha=0.4)

handles, labels = ax_val.get_legend_handles_labels()
extra = [
    Line2D([0], [0], marker='^', color='grey', ls='none', markersize=9,
           markeredgewidth=0, label=f'Failed fit (|r|>{NSIGMA}σ, off-scale)'),
]
ax_val.legend(handles + extra, labels + [h.get_label() for h in extra],
              framealpha=0.9, fontsize=9, ncol=2, loc='upper right')

for cfg, col, mk, off in zip(configs, colors, markers, offsets):
    vals = np.array([v for v, _ in data[cfg][1:]])
    errs = np.array([e for _, e in data[cfg][1:]])
    ok   = np.array([not is_failed(v, e) for v, e in data[cfg][1:]])
    x    = idx_plot

    if ok.any():
        ax_sig.plot(x[ok], errs[ok], mk + '-', color=col, markersize=7,
                    markeredgewidth=0.8, markeredgecolor='white', zorder=3)
    if (~ok).any():
        ax_sig.plot(x[~ok], np.where(errs[~ok] > 0, errs[~ok], 1e-4),
                    marker='x', color=col, ls='none',
                    markersize=11, markeredgewidth=2.5, zorder=4)

ax_sig.set_xticks(idx_plot)
ax_sig.set_xticklabels([str(n) for n in cov_cut_plot])
ax_sig.set_xlabel('Coverage cut', fontsize=11)
ax_sig.set_ylabel(r'$\sigma_r$', fontsize=11)
ax_sig.tick_params(direction='in', which='both', axis='both')
ax_sig.grid(axis='y', which='both', ls=':', alpha=0.4)

fig.tight_layout()
# fig.suptitle('Fitted parameter vs. Coverage cut',
#              fontsize=13, fontweight='bold', y=-0.01)
plt.subplots_adjust(bottom=0.1)
plt.show()

# %%
# Simple comparison plot
fig, ax = plt.subplots(figsize=(8, 4))

for cfg, col, mk, off in zip(configs, colors, markers, offsets):
    vals = np.array([v for v, _ in data[cfg]])
    errs = np.array([e for _, e in data[cfg]])
    ax.errorbar(idx_cov_cut + off, vals, yerr=errs,
                fmt=mk+'-', color=col, label=cfg,
                capsize=3, markersize=6, alpha=0.85)

ax.axhline(0, color='black', lw=1, ls='--', alpha=0.5, label='True value (r = 0)')
ax.set_xticks(idx_cov_cut)
ax.set_xticklabels([str(n) for n in cov_cut])
ax.set_xlabel('Coverage cut', fontsize=11)
ax.set_ylabel('Fitted parameter value', fontsize=11)
ax.legend(fontsize=9, framealpha=0.9)
ax.grid(ls=':', alpha=0.4)
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))

idx_cov_cut = np.arange(len(cov_cut))  # evenly spaced positions so 0.001 isn't stranded far from the rest

for cfg, col, mk in zip(configs, colors, markers):
    errs = np.array([e for _, e in data[cfg]])
    ax.plot(idx_cov_cut, errs, mk+'-', color=col, label=cfg, markersize=7)

# ax.set_yscale('log')
ax.set_xticks(idx_cov_cut)
ax.set_xticklabels([str(n) for n in cov_cut])
ax.set_xlabel('Coverage cut', fontsize=11)
ax.set_ylabel('Uncertainty σ', fontsize=11)
ax.set_title('Evolution of σ with cov_cut', fontsize=12)
ax.grid(ls=':', alpha=0.4)
ax.legend(fontsize=9, framealpha=0.9)

fig.tight_layout()
plt.show()
