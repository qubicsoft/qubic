# %%
# put 0 in the CMB? 
# Analysis of the residuals by putting false into DUST and Synchro
# first 0 in the photon noise, to get only detector noise 
# then 0 in the detector noise, to get only photon noise


# analyse residuals to see some differences 

# interesting to see residuals in components? 

# make a set of maps 
# calculate variance in the pixels for detector and photon

# HABLAR CLAUDIA

# teneidno aproximadamente la varianza en el pixel como numero, puedo sacar el nivel de ruido

# COMO CALCULAR LA CORRELACIÓN DEL RUIDO?
